# %%
pip install youtube-comment-scraper-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install bot-studio
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import googleapiclient.discovery

# %%
API_SERVICE_NAME = "youtube"
API_VERSION = "v3"
API_KEY="AIzaSyAQAwg9uaqDqpGrNh-cuChYygevgjvDXgU"

# %%
VIDEO_ID="bDhvCp3_lYw"

# %%
youtube = googleapiclient.discovery.build(
        API_SERVICE_NAME,API_VERSION, developerKey = API_KEY)

request = youtube.commentThreads().list(
part="snippet,replies",
videoId= VIDEO_ID,
 maxResults=300
)
response = request.execute()
print(response)
# Out:
# {'kind': 'youtube#commentThreadListResponse', 'etag': 'sL-tWtvV3-QU89pRJfYEk4ixlYw', 'nextPageToken': 'Z2V0X25ld2VzdF9maXJzdC0tQ2dnSWdBUVZGN2ZST0JJRkNJZ2dHQUFTQlFpZElCZ0JFZ1VJaVNBWUFCSUZDSWNnR0FBWUFDSU9DZ3dJcjlxcHBBWVFtSm5qX3dF', 'pageInfo': {'totalResults': 100, 'resultsPerPage': 100}, 'items': [{'kind': 'youtube#commentThread', 'etag': 'XKAWph2kE7HpRoIJWZFOTbjQwFU', 'id': 'Ugxe8aBb4F_GHKw75t14AaABAg', 'snippet': {'channelId': 'UC7cs8q-gJRlGwj4A8OmCmXg', 'videoId': 'bDhvCp3_lYw', 'topLevelComment': {'kind': 'youtube#comment', 'etag': 'fPle5gW4vndk7hryFkE_53Dq6y4', 'id': 'Ugxe8aBb4F_GHKw75t14AaABAg', 'snippet': {'channelId': 'UC7cs8q-gJRlGwj4A8OmCmXg', 'videoId': 'bDhvCp3_lYw', 'textDisplay': 'Very well done! Great video. I am working on analyzing and cleaning scraped data from web and this guide is helpful, especially where you mentioned the mistakes.', 'textOriginal': 'Very well done! Great video. I am working on analyzing and cleaning scraped data from web and this guide is helpfu
# ...

# %%
response['items'][0]['snippet']['topLevelComment']['snippet']['textOriginal']
# Out:
# 'Very well done! Great video. I am working on analyzing and cleaning scraped data from web and this guide is helpful, especially where you mentioned the mistakes.'

# %%
ef=  pd.json_normalize(response['items'])

# %%
ef.head()
# Out:
#                     kind                         etag  \
# 0  youtube#commentThread  XKAWph2kE7HpRoIJWZFOTbjQwFU
# 1  youtube#commentThread  ztNB1u889axFJcpi8Dhvu5eU5lM
# 2  youtube#commentThread  rSDIRu3YnheUi2BU_hdekOColjk
# 3  youtube#commentThread  pLUc_aJkKruw6pSJnpGTG42Bxow
# 4  youtube#commentThread  3AcLQkkceG7vKrZnNyPkCO5S5-Y
#
#                            id         snippet.channelId snippet.videoId  \
# 0  Ugxe8aBb4F_GHKw75t14AaABAg  UC7cs8q-gJRlGwj4A8OmCmXg     bDhvCp3_lYw
# 1  Ugx-j1BiA58au55n1jR4AaABAg  UC7cs8q-gJRlGwj4A8OmCmXg     bDhvCp3_lYw
# 2  UgxM_WnCaax0iKy_6jx4AaABAg  UC7cs8q-gJRlGwj4A8OmCmXg     bDhvCp3_lYw
# 3  UgyNDPyFESOood0AVGR4AaABAg  UC7cs8q-gJRlGwj4A8OmCmXg     bDhvCp3_lYw
# 4  UgwUxmLa8ZWINbDZ_zp4AaABAg  UC7cs8q-gJRlGwj4A8OmCmXg     bDhvCp3_lYw
#
#   snippet.topLevelComment.kind snippet.topLevelComment.etag  \
# 0              youtube#comment  fPle5gW4vndk7hryFkE_53Dq6y4
# 1              youtube#comment  sD_vDEBj9gy1zFM4t_oaCL5FHYc
# ...

# %%
ef.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 25 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   kind                                                   100 non-null    object
#  1   etag                                                   100 non-null    object
#  2   id                                                     100 non-null    object
#  3   snippet.channelId                                      100 non-null    object
#  4   snippet.videoId                                        100 non-null    object
#  5   snippet.topLevelComment.kind                           100 non-null    object
#  6   snippet.topLevelComment.etag                           100 non-null    object
#  7   snippet.topLevelComment.id                             100 non-null    object
# ...

# %%
ef.columns=ef.columns.str.removeprefix('snippet.topLevelComment').str.removeprefix('.snippet.').str.removesuffix('.values').str.removesuffix('.comments')

# %%
ef.head()
# Out:
#                     kind                         etag  \
# 0  youtube#commentThread  XKAWph2kE7HpRoIJWZFOTbjQwFU
# 1  youtube#commentThread  ztNB1u889axFJcpi8Dhvu5eU5lM
# 2  youtube#commentThread  rSDIRu3YnheUi2BU_hdekOColjk
# 3  youtube#commentThread  pLUc_aJkKruw6pSJnpGTG42Bxow
# 4  youtube#commentThread  3AcLQkkceG7vKrZnNyPkCO5S5-Y
#
#                            id         snippet.channelId snippet.videoId  \
# 0  Ugxe8aBb4F_GHKw75t14AaABAg  UC7cs8q-gJRlGwj4A8OmCmXg     bDhvCp3_lYw
# 1  Ugx-j1BiA58au55n1jR4AaABAg  UC7cs8q-gJRlGwj4A8OmCmXg     bDhvCp3_lYw
# 2  UgxM_WnCaax0iKy_6jx4AaABAg  UC7cs8q-gJRlGwj4A8OmCmXg     bDhvCp3_lYw
# 3  UgyNDPyFESOood0AVGR4AaABAg  UC7cs8q-gJRlGwj4A8OmCmXg     bDhvCp3_lYw
# 4  UgwUxmLa8ZWINbDZ_zp4AaABAg  UC7cs8q-gJRlGwj4A8OmCmXg     bDhvCp3_lYw
#
#              .kind                        .etag                         .id  \
# 0  youtube#comment  fPle5gW4vndk7hryFkE_53Dq6y4  Ugxe8aBb4F_GHKw75t14AaABAg
# ...

# %%
ef.to_csv(f'comments-{VIDEO_ID}.csv', index=False)

# %% [markdown]
# **Imports**

# %%
# Essentials
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline
import os

# Import functions for data preprocessing & data preparation
from sklearn.preprocessing import LabelEncoder
from sklearn.utils import resample
from sklearn.feature_extraction.text import CountVectorizer
from nltk.sentiment.vader import SentimentIntensityAnalyzer

from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer, LancasterStemmer
from nltk.stem.snowball import SnowballStemmer
from nltk.corpus import stopwords
from nltk.corpus import wordnet
import string
from string import punctuation
import nltk
import re

# %%
data = pd.read_csv(f'comments-{VIDEO_ID}.csv')
data.columns
data1=data.drop(['kind', 'etag','id','snippet.channelId','snippet.videoId', '.kind',
       '.etag', '.id', 'channelId', 'videoId','textDisplay',
       'authorDisplayName', 'authorProfileImageUrl', 'authorChannelUrl',
       'authorChannelId.value', 'canRate', 'viewerRating', 'likeCount',
       'publishedAt', 'updatedAt', 'snippet.canReply',
       'snippet.totalReplyCount', 'snippet.isPublic', 'replies'],axis=1)
data1
# Out:
#                                          textOriginal
# 0   Very well done! Great video. I am working on a...
# 1   For those struggling with the regular expressi...
# 2                                               super
# 3                                           Perfect 👍
# 4                            can i get the excel file
# ..                                                ...
# 95  Pls ...... I don't know how to remove "\n" (pa...
# 96  I saw Clark Kent's phone number went away in t...
# 97  Okay, everyone. Someone changed something some...
# 98  I have been starting at your code and mine try...
# 99  If the df["Phone_Number"].replace('[^a-zA-Z0-9...
#
# [100 rows x 1 columns]

# %% [markdown]
# **Data labelling**

# %%
nltk.download('vader_lexicon')
sentiments = SentimentIntensityAnalyzer()
data1["Positive"] = [sentiments.polarity_scores(i)["pos"] for i in data1["textOriginal"]]
data1["Negative"] = [sentiments.polarity_scores(i)["neg"] for i in data1["textOriginal"]]
data1["Neutral"] = [sentiments.polarity_scores(i)["neu"] for i in data1["textOriginal"]]
data1['Compound'] = [sentiments.polarity_scores(i)["compound"] for i in data1["textOriginal"]]
score = data1["Compound"].values
sentiment = []
for i in score:
    if i >= 0.05 :
        sentiment.append('Positive')
    elif i <= -0.05 :
        sentiment.append('Negative')
    else:
        sentiment.append('Neutral')
data1["Sentiment"] = sentiment
data1.head()
# Out:
# [nltk_data] Error loading vader_lexicon: <urlopen error [WinError
# [nltk_data]     10061] No connection could be made because the target
# [nltk_data]     machine actively refused it>
#                                         textOriginal  Positive  Negative  \
# 0  Very well done! Great video. I am working on a...     0.287     0.073
# 1  For those struggling with the regular expressi...     0.081     0.081
# 2                                              super     1.000     0.000
# 3                                          Perfect 👍     1.000     0.000
# 4                           can i get the excel file     0.429     0.000
#
#    Neutral  Compound Sentiment
# 0    0.640    0.8100  Positive
# 1    0.838    0.0000   Neutral
# 2    0.000    0.5994  Positive
# 3    0.000    0.5719  Positive
# 4    0.571    0.4588  Positive

# %% [markdown]
# **Finaldata**

# %%
data2=data1.drop(['Positive','Negative','Neutral','Compound'],axis=1)
data2.head()
# Out:
#                                         textOriginal Sentiment
# 0  Very well done! Great video. I am working on a...  Positive
# 1  For those struggling with the regular expressi...   Neutral
# 2                                              super  Positive
# 3                                          Perfect 👍  Positive
# 4                           can i get the excel file  Positive

# %%
stop_words = stopwords.words('english')
porter_stemmer = PorterStemmer()
lancaster_stemmer = LancasterStemmer() 
snowball_stemer = SnowballStemmer(language="english")
lzr = WordNetLemmatizer()

# %%
def text_processing(text):   
    # convert text into lowercase
    text = text.lower()

    # remove new line characters in text
    text = re.sub(r'\n',' ', text)
    
    # remove punctuations from text
    text = re.sub('[%s]' % re.escape(punctuation), "", text)
    
    # remove references and hashtags from text
    text = re.sub("^a-zA-Z0-9$,.", "", text)
    
    # remove multiple spaces from text
    text = re.sub(r'\s+', ' ', text, flags=re.I)
    
    # remove special characters from text
    text = re.sub(r'\W', ' ', text)

    text = ' '.join([word for word in word_tokenize(text) if word not in stop_words])
    
    # stemming using porter stemmer from nltk package - msh a7sn 7aga - momken: lancaster, snowball
    # text=' '.join([porter_stemmer.stem(word) for word in word_tokenize(text)])
    # text=' '.join([lancaster_stemmer.stem(word) for word in word_tokenize(text)])
    # text=' '.join([snowball_stemer.stem(word) for word in word_tokenize(text)])
    
    # lemmatizer using WordNetLemmatizer from nltk package
    text=' '.join([lzr.lemmatize(word) for word in word_tokenize(text)])

    return text

# %%
data_copy = data2.copy()
data_copy.textOriginal = data_copy.textOriginal.apply(lambda text: text_processing(text))

# %%
le = LabelEncoder()
data_copy['Sentiment'] = le.fit_transform(data_copy['Sentiment'])

# %%
processed_data = {
    'Sentence':data_copy.textOriginal,
    'Sentiment':data_copy['Sentiment']
}

processed_data = pd.DataFrame(processed_data)
processed_data.head()
# Out:
#                                             Sentence  Sentiment
# 0  well done great video working analyzing cleani...          2
# 1  struggling regular expression 1457 might need ...          1
# 2                                              super          2
# 3                                            perfect          2
# 4                                     get excel file          2

# %%
processed_data['Sentiment'].value_counts()
# Out:
# 2    64
# 1    23
# 0    13
# Name: Sentiment, dtype: int64

# %%
plt.figure(figsize=(8, 6))
data_copy['Sentiment'].value_counts().plot(kind='bar', color=['red', 'grey', 'green'])
plt.title('Distribution of Sentiments')
plt.xlabel('Sentiment')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.show()

# %%
from wordcloud import WordCloud

# Word Cloud for Positive Sentiment
positive_text = ' '.join(data_copy[data_copy['Sentiment'] == 2]['textOriginal'])
wordcloud_positive = WordCloud(width=800, height=400, random_state=21, max_font_size=110).generate(positive_text)
plt.figure(figsize=(10, 7))
plt.imshow(wordcloud_positive, interpolation="bilinear")
plt.title('Word Cloud for Positive Sentiment')
plt.axis('off')
plt.show()

# %%
# Word Cloud for Negative Sentiment
negative_text = ' '.join(data_copy[data_copy['Sentiment'] == 0]['textOriginal'])
wordcloud_negative = WordCloud(width=800, height=400, random_state=21, max_font_size=110).generate(negative_text)

plt.figure(figsize=(10, 7))
plt.imshow(wordcloud_negative, interpolation="bilinear")
plt.title('Word Cloud for Negative Sentiment')
plt.axis('off')
plt.show()

# %%
# Word Cloud for Neutral Sentiment
neutral_text = ' '.join(data_copy[data_copy['Sentiment'] == 1]['textOriginal'])
wordcloud_neutral = WordCloud(width=800, height=400, random_state=21, max_font_size=110).generate(neutral_text)

plt.figure(figsize=(10, 7))
plt.imshow(wordcloud_neutral, interpolation="bilinear")
plt.title('Word Cloud for Neutral Sentiment')
plt.axis('off')
plt.show()

# %%
df_neutral = processed_data[(processed_data['Sentiment']==1)] 
df_negative = processed_data[(processed_data['Sentiment']==0)]
df_positive = processed_data[(processed_data['Sentiment']==2)]

# upsample minority classes
df_negative_upsampled = resample(df_negative, 
                                 replace=True,    
                                 n_samples= 205, 
                                 random_state=42)  

df_neutral_upsampled = resample(df_neutral, 
                                 replace=True,    
                                 n_samples= 205, 
                                 random_state=42)  


# Concatenate the upsampled dataframes with the neutral dataframe
final_data = pd.concat([df_negative_upsampled,df_neutral_upsampled,df_positive])

# %%
final_data['Sentiment'].value_counts()
# Out:
# 0    205
# 1    205
# 2     64
# Name: Sentiment, dtype: int64

# %%
corpus = []
for sentence in final_data['Sentence']:
    corpus.append(sentence)
corpus[0:5]
# Out:
# ['show error dropping useful column',
#  'many mistake',
#  'starting code mine trying drop contact row doesnt like there colon doesnt like either im stuck chatgpt broke asked lol',
#  'need iterate python use dfdfdonotcontact dfphonenumber meet te condition need',
#  'ran code yes trouble x dfdonotcontact x dfdonotcontact dfdonotcontactstrreplacey yes x yes dfdonotcontact dfdonotcontactstrstripes x dfdonotcontact x n dfdonotcontact dfdonotcontactstrreplacen x noo dfdonotcontact dfdonotcontactstrstripo x dfpaying customer x dfpaying customer dfpaying customerstrreplacey yes x yes dfpaying customer dfpaying customerstrstripes x dfpaying customer x n dfpaying customer dfpaying customerstrreplacen x noo dfpaying customer dfpaying customerstrstripo know long']

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features=1500)
X = cv.fit_transform(corpus).toarray()
y = final_data.iloc[:, -1].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
from sklearn.naive_bayes import GaussianNB

# %%
classifier = GaussianNB()
classifier.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
y_pred = classifier.predict(X_test)

# %%
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[64,  0,  0],
#        [ 0, 65,  0],
#        [ 1,  0, 13]], dtype=int64)

# %%
nb_score = accuracy_score(y_test, y_pred)*100
nb_score
# Out:
# 99.3006993006993

# %%
from sklearn.metrics import classification_report

print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99        64
#            1       1.00      1.00      1.00        65
#            2       1.00      0.93      0.96        14
#
#     accuracy                           0.99       143
#    macro avg       0.99      0.98      0.99       143
# weighted avg       0.99      0.99      0.99       143
